# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #KOSPI

# %%
df_KOSPI_200 = pd.read_csv(r"KOSPI 200 Historical Data.csv")

# %%
df_KOSPI_200['Date'] = pd.to_datetime(df_KOSPI_200['Date'])
df_KOSPI_200 = df_KOSPI_200.sort_values(by='Date').reset_index(drop=True)
df_KOSPI_200.set_index('Date', inplace=True)

# %%
df_KOSPI_200['Price'] = pd.to_numeric(df_KOSPI_200['Price'], errors='coerce')

# %%
prices = df_KOSPI_200['Price']
returns_KOSPI_200 = prices.pct_change().dropna()
returns_KOSPI_200 = returns_KOSPI_200.to_frame(name='Return')

# %% [markdown]
# ===============================================================================

# %% [markdown]
# #KOSPI in Normal Market

# %%
df_KOSPI_Norm = pd.DataFrame()

# %%
df_KOSPI_Norm['Use'] = df_KOSPI_200.loc[df_KOSPI_200.index > '2021-01-02', 'Price']
df_KOSPI_Norm['Use']
# Out:
# Date
# 2021-01-04    399.88
# 2021-01-05    406.03
# 2021-01-06    402.08
# 2021-01-07    410.81
# 2021-01-08    430.22
#                ...
# 2025-05-20    347.02
# 2025-05-21    349.38
# 2025-05-22    344.80
# 2025-05-23    345.28
# 2025-05-26    352.11
# Name: Use, Length: 1079, dtype: float64

# %%
prices = df_KOSPI_Norm['Use']
re_KOSPI_Norma = prices.pct_change().dropna()
re_KOSPI_Norma = re_KOSPI_Norma.to_frame(name='Return')

# %%
re_KOSPI_Norma.describe()
# Out:
#             Return
# count  1078.000000
# mean     -0.000047
# std       0.011883
# min      -0.091218
# 25%      -0.007167
# 50%       0.000029
# 75%       0.007122
# max       0.067481

# %% [markdown]
# ===============================================================================

# %% [markdown]
# #ASX All Situation

# %%
df_ASX = pd.read_csv(r"S&P_ASX 200 Historical Data.csv")

# %%
df_ASX['Date'] = pd.to_datetime(df_ASX['Date'])
df_ASX = df_ASX.sort_values(by='Date').reset_index(drop=True)
df_ASX.set_index('Date', inplace=True)
df_ASX['Price'] = df_ASX['Price'].str.replace(',', '', regex=False)
df_ASX['Price'] = pd.to_numeric(df_ASX['Price'], errors='coerce')

# %%
prices = df_ASX['Price']
returns_ASX = prices.pct_change().dropna()
returns_ASX = returns_ASX.to_frame(name='Return')

# %%
returns_ASX.describe()
# Out:
#             Return
# count  2629.000000
# mean      0.000211
# std       0.009660
# min      -0.096998
# 25%      -0.004319
# 50%       0.000793
# 75%       0.005223
# max       0.070007

# %% [markdown]
# ===============================================================================

# %% [markdown]
# #ASX in Normal Market

# %%
df_ASX_Norm = pd.DataFrame()

# %%
df_ASX_Norm['Use'] = df_ASX.loc[df_ASX.index > '2021-01-02', 'Price']
df_ASX_Norm['Use']
# Out:
# Date
# 2021-01-04    6684.2
# 2021-01-05    6681.9
# 2021-01-06    6607.1
# 2021-01-07    6712.0
# 2021-01-08    6757.9
#                ...
# 2025-05-20    8343.3
# 2025-05-21    8386.8
# 2025-05-22    8348.7
# 2025-05-23    8360.9
# 2025-05-26    8361.0
# Name: Use, Length: 1110, dtype: float64

# %%
prices = df_ASX_Norm['Use']
re_ASX_Norm = prices.pct_change().dropna()
re_ASX_Norm = re_ASX_Norm.to_frame(name='Return')  
re_ASX_Norm
# Out:
#               Return
# Date
# 2021-01-05 -0.000344
# 2021-01-06 -0.011194
# 2021-01-07  0.015877
# 2021-01-08  0.006838
# 2021-01-11 -0.008982
# ...              ...
# 2025-05-20  0.005811
# 2025-05-21  0.005214
# 2025-05-22 -0.004543
# 2025-05-23  0.001461
# 2025-05-26  0.000012
#
# [1109 rows x 1 columns]

# %% [markdown]
# ===============================================================================

# %% [markdown]
# #FTSE 250

# %%
df_FTSE_250 = pd.read_csv(r"FTSE Mid-Cap 250 Historical Data.csv")

# %%
df_FTSE_250['Date'] = pd.to_datetime(df_FTSE_250['Date'])
df_FTSE_250 = df_FTSE_250.sort_values(by='Date').reset_index(drop=True)
df_FTSE_250.set_index('Date', inplace=True)
df_FTSE_250['Price'] = df_FTSE_250['Price'].str.replace(',', '', regex=False)
df_FTSE_250['Price'] = pd.to_numeric(df_FTSE_250['Price'], errors='coerce')

# %%
prices = df_FTSE_250['Price']
returns_FTSE_250 = prices.pct_change().dropna()
returns_FTSE_250 = returns_FTSE_250.to_frame(name='Return')

# %% [markdown]
# ===============================================================================

# %% [markdown]
# #FTSE 250 Exclude COVID

# %%
df_FTSE_Norm = pd.DataFrame()

# %%
df_FTSE_Norm['Use'] = df_FTSE_250.loc[df_FTSE_250.index > '2021-01-02', 'Price']
df_FTSE_Norm['Use']
# Out:
# Date
# 2021-01-04    20537.89
# 2021-01-05    20717.37
# 2021-01-06    20973.16
# 2021-01-07    21009.86
# 2021-01-08    21064.24
#                 ...
# 2025-05-19    20961.09
# 2025-05-20    21096.44
# 2025-05-21    20949.67
# 2025-05-22    20799.66
# 2025-05-23    20708.72
# Name: Use, Length: 1107, dtype: float64

# %%
prices = df_FTSE_Norm['Use']
re_FTSE_Norm = prices.pct_change().dropna()
re_FTSE_Norm = re_FTSE_Norm.to_frame(name='Return')  
re_FTSE_Norm
# Out:
#               Return
# Date
# 2021-01-05  0.008739
# 2021-01-06  0.012347
# 2021-01-07  0.001750
# 2021-01-08  0.002588
# 2021-01-11 -0.013678
# ...              ...
# 2025-05-19 -0.000533
# 2025-05-20  0.006457
# 2025-05-21 -0.006957
# 2025-05-22 -0.007160
# 2025-05-23 -0.004372
#
# [1106 rows x 1 columns]

# %% [markdown]
# ===============================================================================
#
#
#
#
#
#
#
#
# #FTSE 100

# %%
df_FTSE_100 = pd.read_csv(r"FTSE 100 Historical Data.csv")

# %%
df_FTSE_100['Date'] = pd.to_datetime(df_FTSE_100['Date'])
df_FTSE_100 = df_FTSE_100.sort_values(by='Date').reset_index(drop=True)
df_FTSE_100.set_index('Date', inplace=True)
df_FTSE_100['Price'] = df_FTSE_100['Price'].str.replace(',', '', regex=False)
df_FTSE_100['Price'] = pd.to_numeric(df_FTSE_100['Price'], errors='coerce')

# %%
prices = df_FTSE_100['Price']
returns_FTSE_100 = prices.pct_change().dropna()
returns_FTSE_100 = returns_FTSE_100.to_frame(name='Return')

# %% [markdown]
# ===============================================================================
#
#
#
#
#
#
#
#
# #FTSE 100 Exclude COVID

# %%
df_FTSE100_Norm = pd.DataFrame()

# %%
df_FTSE100_Norm['Use'] = df_FTSE_100.loc[df_FTSE_100.index > '2021-01-02', 'Price']
df_FTSE100_Norm['Use']
# Out:
# Date
# 2021-01-04    6571.88
# 2021-01-05    6612.25
# 2021-01-06    6841.86
# 2021-01-07    6856.96
# 2021-01-08    6873.26
#                ...
# 2025-05-19    8699.31
# 2025-05-20    8781.12
# 2025-05-21    8786.46
# 2025-05-22    8739.26
# 2025-05-23    8717.97
# Name: Use, Length: 1107, dtype: float64

# %%
prices = df_FTSE100_Norm['Use']
re_FTSE100_Norm = prices.pct_change().dropna()
re_FTSE100_Norm = re_FTSE100_Norm.to_frame(name='Return')  
re_FTSE100_Norm
# Out:
#               Return
# Date
# 2021-01-05  0.006143
# 2021-01-06  0.034725
# 2021-01-07  0.002207
# 2021-01-08  0.002377
# 2021-01-11 -0.010880
# ...              ...
# 2025-05-19  0.001698
# 2025-05-20  0.009404
# 2025-05-21  0.000608
# 2025-05-22 -0.005372
# 2025-05-23 -0.002436
#
# [1106 rows x 1 columns]

# %% [markdown]
# ===============================================================================

# %% [markdown]
# #RESULT & VISUALIZATION

# %%
returns_dict = {
    "ret_KOSPI (KRW)": returns_KOSPI_200,
    "ret_KOSPI_Exclude_COVID (KRW)": re_KOSPI_Norma,
    "ret_ASX (AUD)": returns_ASX,
    "ret_ASX_Exclude_COVID (AUD)": re_ASX_Norm,
    "ret_FTSE_250 (GBP)":returns_FTSE_250,
    "ret_FTSE_250_Exclude_COVID (GBP)":re_FTSE_Norm,
    "ret_FTSE_100 (GBP)":returns_FTSE_100,
    "ret_FTSE_100_Exclude_COVID (GBP)":re_FTSE100_Norm
}

price_dict = {
    "ret_KOSPI (KRW)": df_KOSPI_200['Price'],
    "ret_KOSPI_Exclude_COVID (KRW)": df_KOSPI_Norm['Use'],
    "ret_ASX (AUD)": df_ASX['Price'],
    "ret_ASX_Exclude_COVID (AUD)": df_ASX_Norm['Use'],
    "ret_FTSE_250 (GBP)":df_FTSE_250['Price'],
    "ret_FTSE_250_Exclude_COVID (GBP)":df_FTSE_Norm['Use'],
    "ret_FTSE_100 (GBP)":df_FTSE_100['Price'],
    "ret_FTSE_100_Exclude_COVID (GBP)":df_FTSE100_Norm['Use']
}

# %%
max_abs_change_dict = {}

for name, series in returns_dict.items():
    if isinstance(series, pd.DataFrame):
        series = series.mean(axis=1)

    # หา abs เปลี่ยนแปลงแรงสุด
    abs_series = series.abs()
    max_idx = abs_series.idxmax()
    max_change = abs_series.loc[max_idx]

    # หา Pt และ Pt+1 จากราคาจริง (ต้องมี price_series[name] คู่กัน)
    try:
        price_series = price_dict[name]  # <- ต้องสร้าง price_dict ก่อนนะจ๊ะ
        pt = price_series.shift(1).loc[max_idx]
        pt1 = price_series.loc[max_idx]
    except:
        pt, pt1 = None, None

    max_abs_change_dict[name] = {
        "Max_Abs_Change": max_change,
        "Date": max_idx,
        "Pt": round(pt, 4) if pt is not None else None,
        "Pt+1": round(pt1, 4) if pt1 is not None else None
    }

# %%
max_abs_change_dict
# Out:
# {'ret_KOSPI (KRW)': {'Max_Abs_Change': 0.09149452618021492,
#   'Date': Timestamp('2020-03-24 00:00:00'),
#   'Pt': 201.87,
#   'Pt+1': 220.34},
#  'ret_KOSPI_Exclude_COVID (KRW)': {'Max_Abs_Change': 0.091217788974998,
#   'Date': Timestamp('2024-08-05 00:00:00'),
#   'Pt': 365.17,
#   'Pt+1': 331.86},
#  'ret_ASX (AUD)': {'Max_Abs_Change': 0.09699781560847043,
#   'Date': Timestamp('2020-03-16 00:00:00'),
#   'Pt': 5539.3,
#   'Pt+1': 5002.0},
#  'ret_ASX_Exclude_COVID (AUD)': {'Max_Abs_Change': 0.04536949152542369,
#   'Date': Timestamp('2025-04-10 00:00:00'),
#   'Pt': 7375.0,
#   'Pt+1': 7709.6},
#  'ret_FTSE_250 (GBP)': {'Max_Abs_Change': 0.09353414194286591,
#   'Date': Timestamp('2020-03-12 00:00:00'),
#   'Pt': 17339.23,
#   'Pt+1': 15717.42},
#  'ret_FTSE_250_Exclude_COVID (GBP)': {'Max_Abs_Change': 0.04431245908702541,
#   'Date': Timestamp('2022-03-09 00:00:00'),
#   'Pt': 19217.62,
#   'Pt+1': 20069.2},
#  'ret_FTSE_100 (GBP)': {'Max_Abs_Change': 0.10874463117627453,
#   'Date': Timestamp('2020-03-12 00:00:00'),
#   'Pt': 5876.52,
#   'Pt+1': 5237.48},
#  'ret_FTSE_100_Exclude_COVID (GBP)': {'Max_Abs_Change': 0.04953072306643036,
#   'Date': Timestamp('2025-04-04 00:00:00'),
#   'Pt': 8474.74,
#   'Pt+1': 8054.98}}

# %%
tick_size_dict = {
    "KOSPI": 0.01,
    "ASX": 1,
    "FTSE":0.5
}

contract_size_dict = {
    "KOSPI": 250000,
    "ASX": 10,
    "FTSE":10
}
somc_dict = {
    "KOSPI": "10 Ticks * Tick Size * Contract Size",
    "ASX": " $0.50 per contract for certain equities",
    "FTSE":" SCRAF Ratio * SOM Rate"
}

# %%
def extract_base_name(name):
    if "KOSPI" in name:
        return "KOSPI"
    elif "ASX" in name:
        return "ASX"
    elif "SET50" in name:
        return "SET50"
    elif "FTSE" in name:
        return "FTSE"
    else:
        return name

# %%
summary_data = []

for name, detail in max_abs_change_dict.items():
    base = extract_base_name(name)

    tick = tick_size_dict.get(base, None)
    contract = contract_size_dict.get(base, None)
    somc = somc_dict.get(base, "Unknown")

    summary_data.append({
        "Instrument": name,
        "Tick_Size": tick,
        "Contract_Size": contract,
        "Max_Abs_Change": detail.get("Max_Abs_Change", None),
        "Date": detail.get("Date", None),
        "Pt": detail.get("Pt", None),
        "Pt+1": detail.get("Pt+1", None),
        "SOMC_Policy": somc
    })

# 📊 สร้าง DataFrame
df_summary = pd.DataFrame(summary_data).set_index("Instrument")

# %%
df_summary
# Out:
#                                   Tick_Size  Contract_Size  Max_Abs_Change  \
# Instrument
# ret_KOSPI (KRW)                        0.01         250000        0.091495
# ret_KOSPI_Exclude_COVID (KRW)          0.01         250000        0.091218
# ret_ASX (AUD)                          1.00             10        0.096998
# ret_ASX_Exclude_COVID (AUD)            1.00             10        0.045369
# ret_FTSE_250 (GBP)                     0.50             10        0.093534
# ret_FTSE_250_Exclude_COVID (GBP)       0.50             10        0.044312
# ret_FTSE_100 (GBP)                     0.50             10        0.108745
# ret_FTSE_100_Exclude_COVID (GBP)       0.50             10        0.049531
#
#                                        Date        Pt      Pt+1  \
# Instrument
# ret_KOSPI (KRW)                  2020-03-24    201.87    220.34
# ret_KOSPI_Exclude_COVID (KRW)    2024-08-05    365.17    331.86
# ret_ASX (AUD)                    2020-03-16   5539.30   5002.00
# ret_ASX_Exclude_COVID (AUD)      2025-04-10   7375.00   7709.60
# ret_FTSE_250 (GBP)               2020-03-12  17339.23  15717.42
# ret_FTSE_250_Exclude_COVID (GBP) 2022-03-09  19217.62  20069.20
# ret_FTSE_100 (GBP)               2020-03-12   5876.52   5237.48
# ret_FTSE_100_Exclude_COVID (GBP) 2025-04-04   8474.74   8054.98
#
#                                                                SOMC_Policy
# Instrument
# ret_KOSPI (KRW)                       10 Ticks * Tick Size * Contract Size
# ret_KOSPI_Exclude_COVID (KRW)         10 Ticks * Tick Size * Contract Size
# ret_ASX (AUD)                      $0.50 per contract for certain equities
# ret_ASX_Exclude_COVID (AUD)        $0.50 per contract for certain equities
# ret_FTSE_250 (GBP)                                  SCRAF Ratio * SOM Rate
# ret_FTSE_250_Exclude_COVID (GBP)                    SCRAF Ratio * SOM Rate
# ret_FTSE_100 (GBP)                                  SCRAF Ratio * SOM Rate
# ret_FTSE_100_Exclude_COVID (GBP)                    SCRAF Ratio * SOM Rate

# %%
from IPython.display import display
display(df_summary)
# Out:
#                                   Tick_Size  Contract_Size  Max_Abs_Change  \
# Instrument
# ret_KOSPI (KRW)                        0.01         250000        0.091495
# ret_KOSPI_Exclude_COVID (KRW)          0.01         250000        0.091218
# ret_ASX (AUD)                          1.00             10        0.096998
# ret_ASX_Exclude_COVID (AUD)            1.00             10        0.045369
# ret_FTSE_250 (GBP)                     0.50             10        0.093534
# ret_FTSE_250_Exclude_COVID (GBP)       0.50             10        0.044312
# ret_FTSE_100 (GBP)                     0.50             10        0.108745
# ret_FTSE_100_Exclude_COVID (GBP)       0.50             10        0.049531
#
#                                        Date        Pt      Pt+1  \
# Instrument
# ret_KOSPI (KRW)                  2020-03-24    201.87    220.34
# ret_KOSPI_Exclude_COVID (KRW)    2024-08-05    365.17    331.86
# ret_ASX (AUD)                    2020-03-16   5539.30   5002.00
# ret_ASX_Exclude_COVID (AUD)      2025-04-10   7375.00   7709.60
# ret_FTSE_250 (GBP)               2020-03-12  17339.23  15717.42
# ret_FTSE_250_Exclude_COVID (GBP) 2022-03-09  19217.62  20069.20
# ret_FTSE_100 (GBP)               2020-03-12   5876.52   5237.48
# ret_FTSE_100_Exclude_COVID (GBP) 2025-04-04   8474.74   8054.98
#
#                                                                SOMC_Policy
# Instrument
# ret_KOSPI (KRW)                       10 Ticks * Tick Size * Contract Size
# ret_KOSPI_Exclude_COVID (KRW)         10 Ticks * Tick Size * Contract Size
# ret_ASX (AUD)                      $0.50 per contract for certain equities
# ret_ASX_Exclude_COVID (AUD)        $0.50 per contract for certain equities
# ret_FTSE_250 (GBP)                                  SCRAF Ratio * SOM Rate
# ret_FTSE_250_Exclude_COVID (GBP)                    SCRAF Ratio * SOM Rate
# ret_FTSE_100 (GBP)                                  SCRAF Ratio * SOM Rate
# ret_FTSE_100_Exclude_COVID (GBP)                    SCRAF Ratio * SOM Rate
